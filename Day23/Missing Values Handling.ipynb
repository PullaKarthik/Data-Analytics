# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics

# %%
df=pd.read_csv('gym_members_exercise_tracking_synthetic_data.csv')
print("Number of missing values per column:")
display(df.isnull().sum())
# Out:
# Number of missing values per column:
# Age                              10
# Gender                           71
# Weight (kg)                      22
# Height (m)                       26
# Max_BPM                          21
# Avg_BPM                          30
# Resting_BPM                      19
# Session_Duration (hours)         23
# Calories_Burned                  23
# Workout_Type                     61
# Fat_Percentage                   16
# Water_Intake (liters)            24
# Workout_Frequency (days/week)    58
# Experience_Level                 57
# BMI                              30
# dtype: int64

# %%
df_cleaned=df.dropna()
display(df_cleaned)
# Out:
#        Age  Gender  Weight (kg)  Height (m) Max_BPM  Avg_BPM  Resting_BPM  \
# 0     34.0  Female         86.7        1.86     174    152.0         74.0
# 1     26.0  Female         84.7        1.83     166    156.0         73.0
# 2     22.0    Male         64.8        1.85     187    166.0         64.0
# 3     54.0  Female         75.3        1.82     187    169.0         58.0
# 4     34.0  Female         52.8        1.74     177    169.0         66.0
# ...    ...     ...          ...         ...     ...      ...          ...
# 1795  54.0    Male         88.5        2.00     173    134.0         58.0
# 1796  52.0    Male         84.3        1.69     164    169.0         54.0
# 1797  47.0    Male         70.1        1.84     188    129.0         67.0
# 1798  35.0    Male         49.3        1.71     180    152.0         73.0
# 1799  40.0    Male         79.5        1.92     184    156.0         52.0
#
#       Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
display(df_cleaned.isnull().sum())
df_cleaned.info()
# Out:
# Age                              0
# Gender                           0
# Weight (kg)                      0
# Height (m)                       0
# Max_BPM                          0
# Avg_BPM                          0
# Resting_BPM                      0
# Session_Duration (hours)         0
# Calories_Burned                  0
# Workout_Type                     0
# Fat_Percentage                   0
# Water_Intake (liters)            0
# Workout_Frequency (days/week)    0
# Experience_Level                 0
# BMI                              0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Index: 1359 entries, 0 to 1799
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            1359 non-null   float64
#  1   Gender                         1359 non-null   object
#  2   Weight (kg)                    1359 non-null   float64
# ...

# %%
display(df_cleaned.mean(numeric_only=True))
# Out:
# Age                                34.510670
# Weight (kg)                        67.539809
# Height (m)                          1.738668
# Avg_BPM                           146.097866
# Resting_BPM                        63.863870
# Session_Duration (hours)            1.389338
# Calories_Burned                  1034.690949
# Fat_Percentage                     23.432230
# Water_Intake (liters)               2.732671
# Workout_Frequency (days/week)       3.351729
# Experience_Level                    1.827815
# BMI                                20.078057
# dtype: float64

# %%
display(df_cleaned.mode())
# Out:
#     Age  Gender  Weight (kg)  Height (m) Max_BPM  Avg_BPM  Resting_BPM  \
# 0  18.0  Female         40.0         2.0     192    169.0         74.0
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                       2.0           1783.0     Strength            10.0
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# 0                    3.4                            3.0               2.0
#
#      BMI
# 0  12.32

# %%
display(df_cleaned.median(numeric_only=True))
# Out:
# Age                                33.00
# Weight (kg)                        65.10
# Height (m)                          1.73
# Avg_BPM                           145.00
# Resting_BPM                        65.00
# Session_Duration (hours)            1.37
# Calories_Burned                  1032.00
# Fat_Percentage                     24.10
# Water_Intake (liters)               2.80
# Workout_Frequency (days/week)       3.00
# Experience_Level                    2.00
# BMI                                18.71
# dtype: float64

# %%
display(df_cleaned.var(numeric_only=True))
# Out:
# Age                                 150.831808
# Weight (kg)                         392.563473
# Height (m)                            0.015339
# Avg_BPM                             235.614127
# Resting_BPM                          62.457891
# Session_Duration (hours)              0.138214
# Calories_Burned                  104743.814579
# Fat_Percentage                       34.801332
# Water_Intake (liters)                 0.500773
# Workout_Frequency (days/week)         0.914487
# Experience_Level                      0.552068
# BMI                                  44.842665
# dtype: float64

# %%
display(df_cleaned.std(numeric_only=True))
# Out:
# Age                               12.281360
# Weight (kg)                       19.813215
# Height (m)                         0.123852
# Avg_BPM                           15.349727
# Resting_BPM                        7.903030
# Session_Duration (hours)           0.371772
# Calories_Burned                  323.641491
# Fat_Percentage                     5.899265
# Water_Intake (liters)              0.707653
# Workout_Frequency (days/week)      0.956288
# Experience_Level                   0.743013
# BMI                                6.696467
# dtype: float64

# %%
display(df_cleaned.select_dtypes(include='number').apply(lambda col: (col - col.mean()).abs().mean()))
# Out:
# Age                               10.640023
# Weight (kg)                       16.091891
# Height (m)                         0.099488
# Avg_BPM                           13.459170
# Resting_BPM                        7.083369
# Session_Duration (hours)           0.299310
# Calories_Burned                  260.841675
# Fat_Percentage                     4.653013
# Water_Intake (liters)              0.621741
# Workout_Frequency (days/week)      0.827297
# Experience_Level                   0.623754
# BMI                                5.275765
# dtype: float64
