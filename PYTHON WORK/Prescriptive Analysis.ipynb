# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import statistics

# %%
patient=["Vishwa","Chaitanya","Prabhu","Ganesh","Venkat","Varma","Manju"]
age=[92,95,84,83,76,87,79]
condition=['Serious','Very_serious','Critical','Normal','Normal','Serious','Very_serious']
oxygen=[80,85,90,80,95,100,90]
available_beds=15

# %%
print("------Patients Dataset------")
for i in range(len(patient)):
    print(patient[i],age[i],condition[i],oxygen[i])
# Out:
# ------Patients Dataset------
# Vishwa 92 Serious 80
# Chaitanya 95 Very_serious 85
# Prabhu 84 Critical 90
# Ganesh 83 Normal 80
# Venkat 76 Normal 95
# Varma 87 Serious 100
# Manju 79 Very_serious 90

# %%
for i in range(len(patient)):
    if oxygen[i] < 85:
        print("Patients to be sent to ICU:",patient[i])
# Out:
# Patients to be sent to ICU: Vishwa
# Patients to be sent to ICU: Ganesh

# %%
for i in range(len(patient)):
    if oxygen[i] <= 90 and oxygen[i] >= 85:
        print("Patients to be sent under observation:",patient[i])
# Out:
# Patients to be sent under observation: Chaitanya
# Patients to be sent under observation: Prabhu
# Patients to be sent under observation: Manju

# %%
for i in range(len(patient)):
    if oxygen[i] <= 95 and oxygen[i] > 90:
        print("Patients to be sent under general:",patient[i])
# Out:
# Patients to be sent under general: Venkat

# %%
for i in range(len(patient)):
    if oxygen[i] > 95:
        print("Patient is healthy:",patient[i])
# Out:
# Patient is healthy: Varma
